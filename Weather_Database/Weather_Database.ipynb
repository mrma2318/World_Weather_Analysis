# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size = 2000)
lngs = np.random.uniform(low=-180, high=180, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 752

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
import sys
sys.path.insert(0, '/Users/morgananderson/Desktop/Class/World_Weather_Analysis')
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_weather = requests.get(city_url).json()
        
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        current_description = city_weather["weather"][0]["description"]
        
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": current_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | east london
# Processing Record 2 of Set 1 | raudeberg
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | butaritari
# Processing Record 5 of Set 1 | alice springs
# Processing Record 6 of Set 1 | skagastrond
# City not found. Skipping...
# Processing Record 7 of Set 1 | guerrero negro
# Processing Record 8 of Set 1 | maraa
# Processing Record 9 of Set 1 | tuktoyaktuk
# Processing Record 10 of Set 1 | panama city
# Processing Record 11 of Set 1 | cape town
# Processing Record 12 of Set 1 | corn island
# Processing Record 13 of Set 1 | hermanus
# Processing Record 14 of Set 1 | shingu
# Processing Record 15 of Set 1 | kamsack
# Processing Record 16 of Set 1 | toshkivka
# Processing Record 17 of Set 1 | kutum
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | nikolskoye
# Processing Record 20 of Set 1 | shenjiamen
# Processing Record 21 of Set 1 | mahebourg
# Processing Record 22 of Set 1 | darhan
# Processing Record 23 of Set 1 | tanete
# Processing Record 24 of Set 1 | ribeira grande
# Processing Record 25 of Set 1 | ambunti
# Processing Record 26 of Set 1 | avarua
# Processing Record 27 of Set 1 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 28 of Set 1 | nantucket
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | abu samrah
# Processing Record 31 of Set 1 | fevralsk
# City not found. Skipping...
# Processing Record 32 of Set 1 | marsabit
# Processing Record 33 of Set 1 | saint-philippe
# Processing Record 34 of Set 1 | arraial do cabo
# Processing Record 35 of Set 1 | fortuna
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 1 | rikitea
# Processing Record 39 of Set 1 | padang
# Processing Record 40 of Set 1 | busselton
# Processing Record 41 of Set 1 | hammerfest
# Processing Record 42 of Set 1 | latisana
# Processing Record 43 of Set 1 | georgetown
# Processing Record 44 of Set 1 | muroto
# Processing Record 45 of Set 1 | mataura
# Processing Record 46 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 1 | burlatskoye
# Processing Record 48 of Set 1 | puerto ayora
# Processing Record 49 of Set 1 | hithadhoo
# Processing Record 50 of Set 1 | alekseyevsk
# Processing Record 1 of Set 2 | sibolga
# Processing Record 2 of Set 2 | kavieng
# Processing Record 3 of Set 2 | vao
# Processing Record 4 of Set 2 | kapaa
# Processing Record 5 of Set 2 | bluff
# Processing Record 6 of Set 2 | kamenka
# Processing Record 7 of Set 2 | iqaluit
# Processing Record 8 of Set 2 | severo-kurilsk
# Processing Record 9 of Set 2 | bredasdorp
# Processing Record 10 of Set 2 | buraydah
# Processing Record 11 of Set 2 | ostrovnoy
# Processing Record 12 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 2 | korla
# Processing Record 14 of Set 2 | yellowknife
# Processing Record 15 of Set 2 | mar del plata
# Processing Record 16 of Set 2 | constitucion
# Processing Record 17 of Set 2 | solnechnyy
# Processing Record 18 of Set 2 | kodiak
# Processing Record 19 of Set 2 | muros
# Processing Record 20 of Set 2 | ahipara
# Processing Record 21 of Set 2 | chokurdakh
# Processing Record 22 of Set 2 | olafsvik
# Processing Record 23 of Set 2 | faanui
# Processing Record 24 of Set 2 | paamiut
# Processing Record 25 of Set 2 | doha
# Processing Record 26 of Set 2 | qaanaaq
# Processing Record 27 of Set 2 | clyde river
# Processing Record 28 of Set 2 | saldanha
# Processing Record 29 of Set 2 | carhuamayo
# Processing Record 30 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 2 | aksu
# Processing Record 32 of Set 2 | cayhagan
# Processing Record 33 of Set 2 | thompson
# Processing Record 34 of Set 2 | lebu
# Processing Record 35 of Set 2 | kaitangata
# Processing Record 36 of Set 2 | nadym
# Processing Record 37 of Set 2 | provideniya
# Processing Record 38 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 2 | nemuro
# Processing Record 40 of Set 2 | berlevag
# Processing Record 41 of Set 2 | airai
# Processing Record 42 of Set 2 | boa vista
# Processing Record 43 of Set 2 | cayenne
# Processing Record 44 of Set 2 | vostok
# Processing Record 45 of Set 2 | albany
# Processing Record 46 of Set 2 | upernavik
# Processing Record 47 of Set 2 | tasiilaq
# Processing Record 48 of Set 2 | bengkulu
# Processing Record 49 of Set 2 | port hedland
# Processing Record 50 of Set 2 | talnakh
# Processing Record 1 of Set 3 | norman wells
# Processing Record 2 of Set 3 | gazni
# City not found. Skipping...
# Processing Record 3 of Set 3 | bethel
# Processing Record 4 of Set 3 | buala
# Processing Record 5 of Set 3 | meadow lake
# Processing Record 6 of Set 3 | hasaki
# Processing Record 7 of Set 3 | severo-yeniseyskiy
# Processing Record 8 of Set 3 | barrow
# Processing Record 9 of Set 3 | simao
# Processing Record 10 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 3 | leningradskiy
# Processing Record 12 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 3 | khatanga
# Processing Record 14 of Set 3 | spirit river
# Processing Record 15 of Set 3 | lososina
# Processing Record 16 of Set 3 | ilulissat
# Processing Record 17 of Set 3 | chulym
# Processing Record 18 of Set 3 | piracanjuba
# Processing Record 19 of Set 3 | blackburn
# Processing Record 20 of Set 3 | changtu
# Processing Record 21 of Set 3 | port hardy
# Processing Record 22 of Set 3 | kulykiv
# Processing Record 23 of Set 3 | pevek
# Processing Record 24 of Set 3 | cabedelo
# Processing Record 25 of Set 3 | yumen
# Processing Record 26 of Set 3 | half moon bay
# Processing Record 27 of Set 3 | san vicente
# Processing Record 28 of Set 3 | tabuk
# Processing Record 29 of Set 3 | husavik
# Processing Record 30 of Set 3 | luderitz
# Processing Record 31 of Set 3 | seguela
# Processing Record 32 of Set 3 | hobart
# Processing Record 33 of Set 3 | naze
# Processing Record 34 of Set 3 | goderich
# Processing Record 35 of Set 3 | zambezi
# Processing Record 36 of Set 3 | atuona
# Processing Record 37 of Set 3 | uray
# Processing Record 38 of Set 3 | lata
# Processing Record 39 of Set 3 | byron bay
# Processing Record 40 of Set 3 | sao filipe
# Processing Record 41 of Set 3 | itaituba
# Processing Record 42 of Set 3 | umm lajj
# Processing Record 43 of Set 3 | lluta
# Processing Record 44 of Set 3 | kaduna
# Processing Record 45 of Set 3 | matara
# Processing Record 46 of Set 3 | pacific grove
# Processing Record 47 of Set 3 | clovis
# Processing Record 48 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 3 | dikson
# Processing Record 50 of Set 3 | college
# Processing Record 1 of Set 4 | port elizabeth
# Processing Record 2 of Set 4 | malanje
# Processing Record 3 of Set 4 | katima mulilo
# Processing Record 4 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 4 | roald
# Processing Record 6 of Set 4 | geresk
# City not found. Skipping...
# Processing Record 7 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 8 of Set 4 | new norfolk
# Processing Record 9 of Set 4 | san patricio
# Processing Record 10 of Set 4 | saint-augustin
# Processing Record 11 of Set 4 | cherskiy
# Processing Record 12 of Set 4 | maymanak
# City not found. Skipping...
# Processing Record 13 of Set 4 | victoria
# Processing Record 14 of Set 4 | eyl
# Processing Record 15 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 16 of Set 4 | codrington
# Processing Record 17 of Set 4 | kirakira
# Processing Record 18 of Set 4 | nelson bay
# Processing Record 19 of Set 4 | waitati
# Processing Record 20 of Set 4 | dickinson
# Processing Record 21 of Set 4 | dafeng
# Processing Record 22 of Set 4 | vilcun
# Processing Record 23 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 4 | souillac
# Processing Record 25 of Set 4 | ketchikan
# Processing Record 26 of Set 4 | pahrump
# Processing Record 27 of Set 4 | bambous virieux
# Processing Record 28 of Set 4 | chapais
# Processing Record 29 of Set 4 | bubaque
# Processing Record 30 of Set 4 | longyearbyen
# Processing Record 31 of Set 4 | acapulco
# Processing Record 32 of Set 4 | ewa beach
# Processing Record 33 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 34 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 4 | axim
# Processing Record 36 of Set 4 | naron
# Processing Record 37 of Set 4 | luorong
# Processing Record 38 of Set 4 | sumbawa
# City not found. Skipping...
# Processing Record 39 of Set 4 | baraboo
# Processing Record 40 of Set 4 | misratah
# Processing Record 41 of Set 4 | saint-paul
# Processing Record 42 of Set 4 | keffi
# Processing Record 43 of Set 4 | castro
# Processing Record 44 of Set 4 | hobyo
# Processing Record 45 of Set 4 | port alfred
# Processing Record 46 of Set 4 | kusk
# City not found. Skipping...
# Processing Record 47 of Set 4 | balikpapan
# Processing Record 48 of Set 4 | eshowe
# Processing Record 49 of Set 4 | waverley
# Processing Record 50 of Set 4 | waldoboro
# Processing Record 1 of Set 5 | esperance
# Processing Record 2 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 3 of Set 5 | digboi
# Processing Record 4 of Set 5 | teya
# Processing Record 5 of Set 5 | koungheul
# Processing Record 6 of Set 5 | vardo
# Processing Record 7 of Set 5 | beringovskiy
# Processing Record 8 of Set 5 | saint george
# Processing Record 9 of Set 5 | ancud
# Processing Record 10 of Set 5 | farah
# Processing Record 11 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 5 | tenenkou
# Processing Record 13 of Set 5 | san quintin
# Processing Record 14 of Set 5 | cumaribo
# City not found. Skipping...
# Processing Record 15 of Set 5 | benghazi
# Processing Record 16 of Set 5 | bumba
# Processing Record 17 of Set 5 | kudahuvadhoo
# Processing Record 18 of Set 5 | luza
# Processing Record 19 of Set 5 | camacha
# Processing Record 20 of Set 5 | huarmey
# Processing Record 21 of Set 5 | portland
# Processing Record 22 of Set 5 | oda
# Processing Record 23 of Set 5 | geraldton
# Processing Record 24 of Set 5 | fredericksburg
# Processing Record 25 of Set 5 | san jeronimo
# Processing Record 26 of Set 5 | tuatapere
# Processing Record 27 of Set 5 | kadykchan
# City not found. Skipping...
# Processing Record 28 of Set 5 | hilo
# Processing Record 29 of Set 5 | la ronge
# Processing Record 30 of Set 5 | mount isa
# Processing Record 31 of Set 5 | saskylakh
# Processing Record 32 of Set 5 | takhtamygda
# Processing Record 33 of Set 5 | port augusta
# Processing Record 34 of Set 5 | yar-sale
# Processing Record 35 of Set 5 | kotlas
# Processing Record 36 of Set 5 | hami
# Processing Record 37 of Set 5 | tsaratanana
# Processing Record 38 of Set 5 | leh
# Processing Record 39 of Set 5 | iskateley
# Processing Record 40 of Set 5 | taungdwingyi
# Processing Record 41 of Set 5 | beaverlodge
# Processing Record 42 of Set 5 | matay
# Processing Record 43 of Set 5 | ixtapa
# Processing Record 44 of Set 5 | dobrun
# Processing Record 45 of Set 5 | kalmunai
# Processing Record 46 of Set 5 | ambulu
# Processing Record 47 of Set 5 | iwanai
# Processing Record 48 of Set 5 | torbay
# Processing Record 49 of Set 5 | washington
# Processing Record 50 of Set 5 | piranshahr
# Processing Record 1 of Set 6 | ninghai
# Processing Record 2 of Set 6 | porecatu
# Processing Record 3 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 4 of Set 6 | brookings
# Processing Record 5 of Set 6 | kloulklubed
# Processing Record 6 of Set 6 | talas
# Processing Record 7 of Set 6 | mahibadhoo
# Processing Record 8 of Set 6 | gualeguay
# Processing Record 9 of Set 6 | abiy adi
# City not found. Skipping...
# Processing Record 10 of Set 6 | polunochnoye
# Processing Record 11 of Set 6 | george
# Processing Record 12 of Set 6 | cidreira
# Processing Record 13 of Set 6 | tromso
# Processing Record 14 of Set 6 | laguna
# Processing Record 15 of Set 6 | dudinka
# Processing Record 16 of Set 6 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 17 of Set 6 | edson
# Processing Record 18 of Set 6 | tanout
# Processing Record 19 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 6 | praia da vitoria
# Processing Record 21 of Set 6 | mentougou
# Processing Record 22 of Set 6 | rawson
# Processing Record 23 of Set 6 | durham
# Processing Record 24 of Set 6 | yatou
# Processing Record 25 of Set 6 | mangrol
# Processing Record 26 of Set 6 | atlantic city
# Processing Record 27 of Set 6 | luau
# Processing Record 28 of Set 6 | hay river
# Processing Record 29 of Set 6 | hays
# Processing Record 30 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 6 | flinders
# Processing Record 33 of Set 6 | belyy yar
# Processing Record 34 of Set 6 | tabialan
# City not found. Skipping...
# Processing Record 35 of Set 6 | praia
# Processing Record 36 of Set 6 | luanda
# Processing Record 37 of Set 6 | eureka
# Processing Record 38 of Set 6 | ponta do sol
# Processing Record 39 of Set 6 | ouesso
# Processing Record 40 of Set 6 | grand gaube
# Processing Record 41 of Set 6 | moron
# Processing Record 42 of Set 6 | borba
# Processing Record 43 of Set 6 | mergui
# City not found. Skipping...
# Processing Record 44 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 45 of Set 6 | dunedin
# Processing Record 46 of Set 6 | nueve de julio
# Processing Record 47 of Set 6 | mehamn
# Processing Record 48 of Set 6 | south valley
# Processing Record 49 of Set 6 | nanortalik
# Processing Record 50 of Set 6 | quatre cocos
# Processing Record 1 of Set 7 | namatanai
# Processing Record 2 of Set 7 | xiaoyi
# Processing Record 3 of Set 7 | caruray
# Processing Record 4 of Set 7 | sergeyevka
# Processing Record 5 of Set 7 | urgut
# Processing Record 6 of Set 7 | sitka
# Processing Record 7 of Set 7 | salalah
# Processing Record 8 of Set 7 | sakaraha
# Processing Record 9 of Set 7 | kyakhta
# Processing Record 10 of Set 7 | redmond
# Processing Record 11 of Set 7 | gawler
# Processing Record 12 of Set 7 | riacho de santana
# Processing Record 13 of Set 7 | placido de castro
# Processing Record 14 of Set 7 | trairi
# Processing Record 15 of Set 7 | vestmannaeyjar
# Processing Record 16 of Set 7 | isangel
# Processing Record 17 of Set 7 | skjervoy
# Processing Record 18 of Set 7 | asau
# Processing Record 19 of Set 7 | yakeshi
# Processing Record 20 of Set 7 | harrison
# Processing Record 21 of Set 7 | soria
# Processing Record 22 of Set 7 | kangaatsiaq
# Processing Record 23 of Set 7 | lompoc
# Processing Record 24 of Set 7 | atar
# Processing Record 25 of Set 7 | lagoa
# Processing Record 26 of Set 7 | bathsheba
# Processing Record 27 of Set 7 | aquidauana
# Processing Record 28 of Set 7 | narsaq
# Processing Record 29 of Set 7 | catuday
# Processing Record 30 of Set 7 | sola
# Processing Record 31 of Set 7 | carnarvon
# Processing Record 32 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 7 | meulaboh
# Processing Record 34 of Set 7 | chokwe
# Processing Record 35 of Set 7 | salym
# Processing Record 36 of Set 7 | bosaso
# Processing Record 37 of Set 7 | henties bay
# Processing Record 38 of Set 7 | jalu
# Processing Record 39 of Set 7 | maarianhamina
# Processing Record 40 of Set 7 | altay
# Processing Record 41 of Set 7 | usinsk
# Processing Record 42 of Set 7 | poum
# Processing Record 43 of Set 7 | rosetta
# Processing Record 44 of Set 7 | mutoko
# Processing Record 45 of Set 7 | aksarka
# Processing Record 46 of Set 7 | rocha
# Processing Record 47 of Set 7 | tommot
# Processing Record 48 of Set 7 | acajutla
# Processing Record 49 of Set 7 | chabahar
# Processing Record 50 of Set 7 | lensk
# Processing Record 1 of Set 8 | haines junction
# Processing Record 2 of Set 8 | wamba
# Processing Record 3 of Set 8 | karratha
# Processing Record 4 of Set 8 | faya
# Processing Record 5 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 6 of Set 8 | tahoua
# Processing Record 7 of Set 8 | mount gambier
# Processing Record 8 of Set 8 | ridgecrest
# Processing Record 9 of Set 8 | hachinohe
# Processing Record 10 of Set 8 | santiago de cao
# Processing Record 11 of Set 8 | general pico
# Processing Record 12 of Set 8 | itarema
# Processing Record 13 of Set 8 | port blair
# Processing Record 14 of Set 8 | channel-port aux basques
# Processing Record 15 of Set 8 | hambantota
# Processing Record 16 of Set 8 | karoi
# Processing Record 17 of Set 8 | flin flon
# Processing Record 18 of Set 8 | jaffrey
# Processing Record 19 of Set 8 | whitehorse
# Processing Record 20 of Set 8 | pishva
# Processing Record 21 of Set 8 | lorengau
# Processing Record 22 of Set 8 | rudbar
# Processing Record 23 of Set 8 | christchurch
# Processing Record 24 of Set 8 | ballina
# Processing Record 25 of Set 8 | curtisoara
# Processing Record 26 of Set 8 | takoradi
# Processing Record 27 of Set 8 | glenwood springs
# Processing Record 28 of Set 8 | greymouth
# Processing Record 29 of Set 8 | santa maria
# Processing Record 30 of Set 8 | bairnsdale
# Processing Record 31 of Set 8 | lavrentiya
# Processing Record 32 of Set 8 | eirunepe
# Processing Record 33 of Set 8 | armacao dos buzios
# City not found. Skipping...
# Processing Record 34 of Set 8 | jardim
# Processing Record 35 of Set 8 | amberley
# Processing Record 36 of Set 8 | keflavik
# Processing Record 37 of Set 8 | san policarpo
# Processing Record 38 of Set 8 | hovd
# Processing Record 39 of Set 8 | north bend
# Processing Record 40 of Set 8 | tazovskiy
# Processing Record 41 of Set 8 | sedelnikovo
# City not found. Skipping...
# Processing Record 42 of Set 8 | melendugno
# Processing Record 43 of Set 8 | kavaratti
# Processing Record 44 of Set 8 | svetlogorsk
# Processing Record 45 of Set 8 | tirumullaivasal
# Processing Record 46 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 8 | ulyanovo
# City not found. Skipping...
# Processing Record 48 of Set 8 | ust-maya
# Processing Record 49 of Set 8 | tezu
# Processing Record 50 of Set 8 | sur
# Processing Record 1 of Set 9 | paramaribo
# Processing Record 2 of Set 9 | vila franca do campo
# Processing Record 3 of Set 9 | jiazi
# Processing Record 4 of Set 9 | srednekolymsk
# Processing Record 5 of Set 9 | santiago del estero
# Processing Record 6 of Set 9 | hamilton
# Processing Record 7 of Set 9 | tailai
# Processing Record 8 of Set 9 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 9 of Set 9 | honiara
# Processing Record 10 of Set 9 | alta floresta
# Processing Record 11 of Set 9 | puerto narino
# Processing Record 12 of Set 9 | port macquarie
# Processing Record 13 of Set 9 | azare
# Processing Record 14 of Set 9 | ajdabiya
# Processing Record 15 of Set 9 | riviere-au-renard
# Processing Record 16 of Set 9 | rio gallegos
# Processing Record 17 of Set 9 | tiksi
# Processing Record 18 of Set 9 | pontianak
# Processing Record 19 of Set 9 | marsa matruh
# Processing Record 20 of Set 9 | karlstad
# Processing Record 21 of Set 9 | sabang
# Processing Record 22 of Set 9 | shimoda
# Processing Record 23 of Set 9 | piranhas
# Processing Record 24 of Set 9 | quepos
# Processing Record 25 of Set 9 | itoman
# Processing Record 26 of Set 9 | havre-saint-pierre
# Processing Record 27 of Set 9 | pontian kecil
# Processing Record 28 of Set 9 | port lincoln
# Processing Record 29 of Set 9 | lanivtsi
# Processing Record 30 of Set 9 | liwale
# Processing Record 31 of Set 9 | port-gentil
# Processing Record 32 of Set 9 | tura
# Processing Record 33 of Set 9 | ijaki
# City not found. Skipping...
# Processing Record 34 of Set 9 | chico
# Processing Record 35 of Set 9 | palafrugell
# Processing Record 36 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 9 | polyarnyy
# Processing Record 38 of Set 9 | coquimbo
# Processing Record 39 of Set 9 | yanan
# City not found. Skipping...
# Processing Record 40 of Set 9 | hofn
# Processing Record 41 of Set 9 | tigil
# Processing Record 42 of Set 9 | erdemli
# Processing Record 43 of Set 9 | vuktyl
# Processing Record 44 of Set 9 | kuryk
# Processing Record 45 of Set 9 | labuan
# Processing Record 46 of Set 9 | aklavik
# Processing Record 47 of Set 9 | belaya gora
# Processing Record 48 of Set 9 | viedma
# Processing Record 49 of Set 9 | pulandian
# Processing Record 50 of Set 9 | etchoropo
# Processing Record 1 of Set 10 | katsuura
# Processing Record 2 of Set 10 | westport
# Processing Record 3 of Set 10 | harper
# Processing Record 4 of Set 10 | te anau
# Processing Record 5 of Set 10 | waipawa
# Processing Record 6 of Set 10 | chikoy
# City not found. Skipping...
# Processing Record 7 of Set 10 | akyab
# Processing Record 8 of Set 10 | filadelfia
# Processing Record 9 of Set 10 | mantua
# Processing Record 10 of Set 10 | mitsamiouli
# Processing Record 11 of Set 10 | irece
# Processing Record 12 of Set 10 | purepero
# Processing Record 13 of Set 10 | sudogda
# Processing Record 14 of Set 10 | huntley
# Processing Record 15 of Set 10 | kendari
# Processing Record 16 of Set 10 | bontang
# Processing Record 17 of Set 10 | southbridge
# Processing Record 18 of Set 10 | stromness
# Processing Record 19 of Set 10 | belen de umbria
# Processing Record 20 of Set 10 | quthing
# Processing Record 21 of Set 10 | paris
# Processing Record 22 of Set 10 | pundaguitan
# Processing Record 23 of Set 10 | mecca
# Processing Record 24 of Set 10 | izvestkovyy
# Processing Record 25 of Set 10 | north platte
# Processing Record 26 of Set 10 | xam nua
# Processing Record 27 of Set 10 | canakkale
# Processing Record 28 of Set 10 | necochea
# Processing Record 29 of Set 10 | pontiac
# Processing Record 30 of Set 10 | athabasca
# Processing Record 31 of Set 10 | conde
# Processing Record 32 of Set 10 | berdigestyakh
# Processing Record 33 of Set 10 | kirkenaer
# Processing Record 34 of Set 10 | mazatlan
# Processing Record 35 of Set 10 | altoona
# Processing Record 36 of Set 10 | araouane
# Processing Record 37 of Set 10 | hollister
# Processing Record 38 of Set 10 | mawlaik
# Processing Record 39 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 40 of Set 10 | uttarkashi
# Processing Record 41 of Set 10 | morganton
# Processing Record 42 of Set 10 | barmer
# Processing Record 43 of Set 10 | dali
# Processing Record 44 of Set 10 | qianan
# Processing Record 45 of Set 10 | chuy
# Processing Record 46 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 47 of Set 10 | beidao
# Processing Record 48 of Set 10 | okitipupa
# Processing Record 49 of Set 10 | rozzano
# Processing Record 50 of Set 10 | lydenburg
# Processing Record 1 of Set 11 | los llanos de aridane
# Processing Record 2 of Set 11 | tomatlan
# Processing Record 3 of Set 11 | batagay
# Processing Record 4 of Set 11 | khandyga
# Processing Record 5 of Set 11 | gat
# Processing Record 6 of Set 11 | albanel
# Processing Record 7 of Set 11 | sainte-suzanne
# Processing Record 8 of Set 11 | kothi
# Processing Record 9 of Set 11 | tottori
# Processing Record 10 of Set 11 | katherine
# Processing Record 11 of Set 11 | ndungu
# Processing Record 12 of Set 11 | novaya igirma
# Processing Record 13 of Set 11 | kandrian
# Processing Record 14 of Set 11 | sembe
# Processing Record 15 of Set 11 | cabo san lucas
# Processing Record 16 of Set 11 | kapoeta
# Processing Record 17 of Set 11 | canon city
# Processing Record 18 of Set 11 | luangwa
# Processing Record 19 of Set 11 | ilhabela
# Processing Record 20 of Set 11 | kalianget
# Processing Record 21 of Set 11 | richards bay
# Processing Record 22 of Set 11 | parrita
# Processing Record 23 of Set 11 | comodoro rivadavia
# Processing Record 24 of Set 11 | tabas
# Processing Record 25 of Set 11 | sobolevo
# Processing Record 26 of Set 11 | chaihe
# Processing Record 27 of Set 11 | itarare
# Processing Record 28 of Set 11 | puksoozero
# Processing Record 29 of Set 11 | poya
# Processing Record 30 of Set 11 | okhotsk
# Processing Record 31 of Set 11 | saint-francois
# Processing Record 32 of Set 11 | riyadh
# Processing Record 33 of Set 11 | naraina
# Processing Record 34 of Set 11 | lokomotivnyy
# Processing Record 35 of Set 11 | elektrogorsk
# Processing Record 36 of Set 11 | turukhansk
# Processing Record 37 of Set 11 | svetlaya
# Processing Record 38 of Set 11 | puerto baquerizo moreno
# Processing Record 39 of Set 11 | monte alegre de minas
# Processing Record 40 of Set 11 | noshiro
# Processing Record 41 of Set 11 | gold coast
# Processing Record 42 of Set 11 | liverpool
# Processing Record 43 of Set 11 | namtsy
# Processing Record 44 of Set 11 | zhigansk
# Processing Record 45 of Set 11 | anadyr
# Processing Record 46 of Set 11 | bulalacao
# Processing Record 47 of Set 11 | kula
# Processing Record 48 of Set 11 | lasa
# Processing Record 49 of Set 11 | emba
# Processing Record 50 of Set 11 | egvekinot
# Processing Record 1 of Set 12 | brigantine
# Processing Record 2 of Set 12 | margate
# Processing Record 3 of Set 12 | kawalu
# Processing Record 4 of Set 12 | rengali
# Processing Record 5 of Set 12 | dindori
# Processing Record 6 of Set 12 | san carlos de bariloche
# Processing Record 7 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 8 of Set 12 | uchaly
# Processing Record 9 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 10 of Set 12 | ibra
# Processing Record 11 of Set 12 | trelew
# Processing Record 12 of Set 12 | bantry
# Processing Record 13 of Set 12 | klaksvik
# Processing Record 14 of Set 12 | caborca
# Processing Record 15 of Set 12 | nome
# Processing Record 16 of Set 12 | jasper
# Processing Record 17 of Set 12 | palana
# Processing Record 18 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 19 of Set 12 | nazare
# Processing Record 20 of Set 12 | villa maria
# Processing Record 21 of Set 12 | makinsk
# Processing Record 22 of Set 12 | ouallam
# Processing Record 23 of Set 12 | rabo de peixe
# Processing Record 24 of Set 12 | gongzhuling
# Processing Record 25 of Set 12 | dwarka
# Processing Record 26 of Set 12 | prince rupert
# Processing Record 27 of Set 12 | ternate
# Processing Record 28 of Set 12 | dibaya
# City not found. Skipping...
# Processing Record 29 of Set 12 | mayya
# Processing Record 30 of Set 12 | russkiy aktash
# Processing Record 31 of Set 12 | wanning
# Processing Record 32 of Set 12 | houma
# Processing Record 33 of Set 12 | maragogi
# Processing Record 34 of Set 12 | clarence town
# Processing Record 35 of Set 12 | bandarban
# Processing Record 36 of Set 12 | sorland
# Processing Record 37 of Set 12 | bose
# Processing Record 38 of Set 12 | moussoro
# Processing Record 39 of Set 12 | stornoway
# Processing Record 40 of Set 12 | erzincan
# Processing Record 41 of Set 12 | council bluffs
# Processing Record 42 of Set 12 | san buenaventura
# Processing Record 43 of Set 12 | fonte boa
# Processing Record 44 of Set 12 | dzaoudzi
# Processing Record 45 of Set 12 | vauvert
# Processing Record 46 of Set 12 | ayan
# Processing Record 47 of Set 12 | matamoros
# Processing Record 48 of Set 12 | mundra
# Processing Record 49 of Set 12 | nhulunbuy
# Processing Record 50 of Set 12 | saint cloud
# Processing Record 1 of Set 13 | yeppoon
# Processing Record 2 of Set 13 | beziers
# Processing Record 3 of Set 13 | kruisfontein
# Processing Record 4 of Set 13 | zanjan
# Processing Record 5 of Set 13 | banda aceh
# Processing Record 6 of Set 13 | essau
# Processing Record 7 of Set 13 | grand forks
# Processing Record 8 of Set 13 | rimouski
# Processing Record 9 of Set 13 | nefteyugansk
# Processing Record 10 of Set 13 | whitianga
# Processing Record 11 of Set 13 | salcininkai
# Processing Record 12 of Set 13 | ciechocinek
# Processing Record 13 of Set 13 | sirsa
# Processing Record 14 of Set 13 | verkhnevilyuysk
# Processing Record 15 of Set 13 | magaria
# Processing Record 16 of Set 13 | nidzica
# Processing Record 17 of Set 13 | pitiquito
# Processing Record 18 of Set 13 | tres arroyos
# Processing Record 19 of Set 13 | portobelo
# Processing Record 20 of Set 13 | pisco
# Processing Record 21 of Set 13 | makakilo city
# Processing Record 22 of Set 13 | garissa
# Processing Record 23 of Set 13 | vila velha
# Processing Record 24 of Set 13 | saint-pierre
# Processing Record 25 of Set 13 | luceville
# City not found. Skipping...
# Processing Record 26 of Set 13 | muisne
# Processing Record 27 of Set 13 | vestbygda
# City not found. Skipping...
# Processing Record 28 of Set 13 | noumea
# Processing Record 29 of Set 13 | manokwari
# Processing Record 30 of Set 13 | northport
# Processing Record 31 of Set 13 | morondava
# Processing Record 32 of Set 13 | grindavik
# Processing Record 33 of Set 13 | raigarh
# Processing Record 34 of Set 13 | sisimiut
# Processing Record 35 of Set 13 | cardston
# Processing Record 36 of Set 13 | auki
# Processing Record 37 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 38 of Set 13 | tongren
# Processing Record 39 of Set 13 | montalvo
# Processing Record 40 of Set 13 | samarai
# Processing Record 41 of Set 13 | kieta
# Processing Record 42 of Set 13 | robertsport
# Processing Record 43 of Set 13 | dawlatabad
# Processing Record 44 of Set 13 | port-cartier
# Processing Record 45 of Set 13 | grants pass
# Processing Record 46 of Set 13 | salmon arm
# Processing Record 47 of Set 13 | akdepe
# Processing Record 48 of Set 13 | yerbogachen
# Processing Record 49 of Set 13 | shumskiy
# Processing Record 50 of Set 13 | kushmurun
# Processing Record 1 of Set 14 | nouadhibou
# Processing Record 2 of Set 14 | eskasem
# City not found. Skipping...
# Processing Record 3 of Set 14 | itambacuri
# Processing Record 4 of Set 14 | havoysund
# Processing Record 5 of Set 14 | imbituba
# Processing Record 6 of Set 14 | caravelas
# Processing Record 7 of Set 14 | saint anthony
# Processing Record 8 of Set 14 | nuevo progreso
# Processing Record 9 of Set 14 | galle
# Processing Record 10 of Set 14 | namibe
# Processing Record 11 of Set 14 | hearst
# Processing Record 12 of Set 14 | palmer
# Processing Record 13 of Set 14 | guymon
# Processing Record 14 of Set 14 | nola
# Processing Record 15 of Set 14 | roebourne
# Processing Record 16 of Set 14 | brae
# Processing Record 17 of Set 14 | warrnambool
# Processing Record 18 of Set 14 | chegdomyn
# Processing Record 19 of Set 14 | chilmari
# Processing Record 20 of Set 14 | tillabery
# City not found. Skipping...
# Processing Record 21 of Set 14 | tolaga bay
# Processing Record 22 of Set 14 | kichera
# Processing Record 23 of Set 14 | batemans bay
# Processing Record 24 of Set 14 | pilar
# Processing Record 25 of Set 14 | amapa
# Processing Record 26 of Set 14 | luang prabang
# Processing Record 27 of Set 14 | calama
# Processing Record 28 of Set 14 | chaska
# Processing Record 29 of Set 14 | comarapa
# Processing Record 30 of Set 14 | phan thiet
# Processing Record 31 of Set 14 | funes
# Processing Record 32 of Set 14 | mocambique
# City not found. Skipping...
# Processing Record 33 of Set 14 | arkadelphia
# Processing Record 34 of Set 14 | sibenik
# Processing Record 35 of Set 14 | mulchen
# Processing Record 36 of Set 14 | joshimath
# Processing Record 37 of Set 14 | iracoubo
# Processing Record 38 of Set 14 | fort saint james
# Processing Record 39 of Set 14 | andenes
# Processing Record 40 of Set 14 | vrangel
# Processing Record 41 of Set 14 | kaifeng
# Processing Record 42 of Set 14 | taoudenni
# Processing Record 43 of Set 14 | yokadouma
# Processing Record 44 of Set 14 | labe
# Processing Record 45 of Set 14 | sept-iles
# Processing Record 46 of Set 14 | bocas del toro
# Processing Record 47 of Set 14 | the valley
# Processing Record 48 of Set 14 | floresta
# Processing Record 49 of Set 14 | komsomolskiy
# Processing Record 50 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 15 | manzil tamim
# City not found. Skipping...
# Processing Record 2 of Set 15 | bad segeberg
# Processing Record 3 of Set 15 | netanya
# Processing Record 4 of Set 15 | shache
# Processing Record 5 of Set 15 | joetsu
# Processing Record 6 of Set 15 | cranbrook
# Processing Record 7 of Set 15 | saint-joseph
# Processing Record 8 of Set 15 | espanola
# Processing Record 9 of Set 15 | varhaug
# Processing Record 10 of Set 15 | san luis
# Processing Record 11 of Set 15 | krasnousolskiy
# City not found. Skipping...
# Processing Record 12 of Set 15 | bayangol
# Processing Record 13 of Set 15 | tabou
# Processing Record 14 of Set 15 | doaba
# Processing Record 15 of Set 15 | foam lake
# Processing Record 16 of Set 15 | ous
# Processing Record 17 of Set 15 | lakes entrance
# Processing Record 18 of Set 15 | mazara del vallo
# Processing Record 19 of Set 15 | linhares
# Processing Record 20 of Set 15 | altagracia de orituco
# Processing Record 21 of Set 15 | abashiri
# Processing Record 22 of Set 15 | kholtoson
# Processing Record 23 of Set 15 | soma
# Processing Record 24 of Set 15 | fujin
# Processing Record 25 of Set 15 | juquia
# Processing Record 26 of Set 15 | san cristobal
# Processing Record 27 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 28 of Set 15 | les cayes
# Processing Record 29 of Set 15 | inuvik
# Processing Record 30 of Set 15 | ozernovskiy
# Processing Record 31 of Set 15 | huicungo
# Processing Record 32 of Set 15 | todos santos
# Processing Record 33 of Set 15 | indianola
# Processing Record 34 of Set 15 | santa cruz de la palma
# Processing Record 35 of Set 15 | ploemeur
# Processing Record 36 of Set 15 | mabaruma
# Processing Record 37 of Set 15 | nishihara
# Processing Record 38 of Set 15 | tautira
# Processing Record 39 of Set 15 | reconquista
# Processing Record 40 of Set 15 | pilane
# Processing Record 41 of Set 15 | olbia
# Processing Record 42 of Set 15 | villa bruzual
# Processing Record 43 of Set 15 | behshahr
# Processing Record 44 of Set 15 | alamosa
# Processing Record 45 of Set 15 | moramanga
# Processing Record 46 of Set 15 | abu jubayhah
# City not found. Skipping...
# Processing Record 47 of Set 15 | bangui
# Processing Record 48 of Set 15 | palauig
# Processing Record 49 of Set 15 | chifeng
# Processing Record 50 of Set 15 | udachnyy
# Processing Record 1 of Set 16 | agadez
# Processing Record 2 of Set 16 | nogales
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 690

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     East London -33.0153   27.9116     61.74       100         100
# 1       Raudeberg  61.9875    5.1352     52.47        42          35
# 2           Vaini -21.2000 -175.2000     71.76        83          20
# 3      Butaritari   3.0707  172.7902     82.11        75         100
# 4   Alice Springs -23.7000  133.8833     57.22        39         100
# 5  Guerrero Negro  27.9769 -114.0611     80.60        62           0
# 6           Maraa  -1.8333  -65.3667     99.19        29          97
# 7     Tuktoyaktuk  69.4541 -133.0374     30.20       100         100
# 8     Panama City   8.9936  -79.5197     87.13        74          40
# 9       Cape Town -33.9258   18.4232     62.10        85          20
#
#    Wind Speed Country     Current Description
# 0        3.44      ZA  thunderstorm with rain
# 1        9.40      NO        scattered clouds
# 2        8.05      TO              few clouds
# 3       17.49      KI         overcast clouds
# 4        5.75      AU         overcast clouds
# 5        9.64      MX               clear sky
# 6        3.87      BR         overcast clouds
# 7       20.71      CA         overcast clouds
# 8       12.66      PA        scattered clouds
# 9       12.66      ZA              few clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     East London      ZA -33.0153   27.9116     61.74       100         100
# 1       Raudeberg      NO  61.9875    5.1352     52.47        42          35
# 2           Vaini      TO -21.2000 -175.2000     71.76        83          20
# 3      Butaritari      KI   3.0707  172.7902     82.11        75         100
# 4   Alice Springs      AU -23.7000  133.8833     57.22        39         100
# 5  Guerrero Negro      MX  27.9769 -114.0611     80.60        62           0
# 6           Maraa      BR  -1.8333  -65.3667     99.19        29          97
# 7     Tuktoyaktuk      CA  69.4541 -133.0374     30.20       100         100
# 8     Panama City      PA   8.9936  -79.5197     87.13        74          40
# 9       Cape Town      ZA -33.9258   18.4232     62.10        85          20
#
#    Wind Speed     Current Description
# 0        3.44  thunderstorm with rain
# 1        9.40        scattered clouds
# 2        8.05              few clouds
# 3       17.49         overcast clouds
# 4        5.75         overcast clouds
# 5        9.64               clear sky
# 6        3.87         overcast clouds
# 7       20.71         overcast clouds
# 8       12.66        scattered clouds
# 9       12.66              few clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
